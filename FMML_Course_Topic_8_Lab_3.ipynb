# %% [markdown]
# <a href="https://colab.research.google.com/github/Dil8eep/FMML_LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 04:38:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   179MB/s    in 0.4s
#
# 2023-05-05 04:38:06 (179 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 36006   0906.2228v2  Equilibrium logic is an approach to nonmonoton...    cs
# 29311  1709.00751v2  In conveyor belt sushi restaurants, billing is...    cs
# 37092  1607.02399v1  Big data analytics applications drive the conv...    cs
# 6125   1608.00159v4  In this paper, we present a new approach to le...  stat
# 26326  1609.08764v2  In this paper we investigate the benefit of au...    cs
# ...             ...                                                ...   ...
# 39066   1008.1150v1  We study the effect of growth on the fingerpri...    cs
# 38277  1509.00533v1  Most speech enhancement algorithms make use of...    cs
# 2133   1603.03980v2  Single Index Models (SIMs) are simple yet flex...  stat
# 24968  1501.04505v2  Deep networks have been successfully applied t...    cs
# 6355   1611.06534v2  We derive an alternative proof for the regret ...  stat
#
#                                                    title  year  \
# 36006  Characterising equilibrium logic and nested lo...  2009
# 29311  Sushi Dish - Object detection and classificati...  2017
# 37092  Translating Bayesian Networks into Entity Rela...  2016
# 6125   Learning Tree-Structured Detection Cascades fo...  2016
# 26326  Understanding data augmentation for classifica...  2016
# ...                                                  ...   ...
# 39066  Modeling the growth of fingerprints improves m...  2010
# 38277  Enhancement and Recognition of Reverberant and...  2015
# 2133   On Learning High Dimensional Structured Single...  2016
# 24968  Robust Visual Tracking via Convolutional Networks  2015
# 6355                  Linear Thompson Sampling Revisited  2016
#
#                                                 keywords
# 36006  [equilibrium, nonmonotonic, reasoning, semanti...
# 29311  [restaurants, calculate, situation, customers,...
# 37092  [analytics, applications, convergence, managem...
# 6125   [classifiers, computing, environments, heterog...
# 26326  [investigate, augmenting, synthetically, class...
# ...                                                  ...
# 39066  [fingerprints, adolescents, juveniles, fingerp...
# 38277  [enhancement, algorithms, transform, frequency...
# 2133   [parametric, monotonic, combination, estimatio...
# 24968  [successfully, representation, consuming, repr...
# 6355   [alternative, stochastic, functioning, structu...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 36006    [equilibrium, nonmonotonic, reasoning, semanti...
# 29311    [restaurants, calculate, situation, customers,...
# 37092    [analytics, applications, convergence, managem...
# 6125     [classifiers, computing, environments, heterog...
# 26326    [investigate, augmenting, synthetically, class...
#                                ...
# 26027    [alternative, segmentation, segmentation, algo...
# 32620    [probabilistic, classification, architecture, ...
# 23081    [factorization, promising, understanding, unce...
# 6946     [recurrent, sequential, vanishing, exploding, ...
# 7697     [theoretical, understanding, attractive, viewp...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8765 words.
# Out of those 4542 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8d4d562e-db3b-4cc6-a878-90c097c8b425" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d4d562e-db3b-4cc6-a878-90c097c8b425")) {                    Plotly.newPlot(                        "8d4d562e-db3b-4cc6-a878-90c097c8b425",                        [{"x":["equivalence","semantical","reductions","nonmonotonic","polynomial","quantifications","additionally","permitted","associated","considered","precisely","computational","skeptical","particular","complexity","quantified","characterising","consistency","equilibrium","different","reasoning","extension","combinations","encodings","arbitrary","semantics","classical","propositional","calculate","customers","developed","identifies","precision","automatically","detection","situation","classification","restaurants","translate","framework","relationship","applications","interactive","component","transformed","available","graphical","application","information","development","translating","conceptual","mathematical","contribution","relationships","convergence","supported","analytics","management","representation","probabilistic","monitoring","constrained","classifiers","accomplish","combining","actigraphy","environments","architecture","computation","motivated","cigarette","respiration","efficient","delivering","objective","computing","recognition","interventions","structured","parameters","potentially","generalization","detectors","resources","integrating","heterogeneous","concentrate","classifier","combination","augmenting","approaches","synthetically","plausible","understanding","additional","experimentally","convolutional","backpropagation","transformations","investigate","generates","overfitting","improving","transforms","synthetic","performance","augmentation","handwritten","experimental","regression","simulated","likelihood","introduces","efficiently","regressors","interdependency","criterion","validation","selection","multimodal","numerical","estimations","parameterized","uncertain","attaching","expressed","qualitative","knowledge","certainty","operators","axiomatization","partially","quadratically","estimation","aggregates","algorithm","furthermore","factorization","nonnegative","extensive","quadratic","autocorrelation","consumption","observations","individual","experiments","measurements","electricity","relaxation","illustrate","recovering","algorithms","effectiveness","incremental","outperforms","benchmark","guarantee","effective","iteration","guarantees","stochastic","implementation","optimization","variables","desirable","preserved","including","projection","iterations","regularization","sacrificing","coordinate","randomized","quantiles","successfully","formulated","procedure","estimators","hypothesis","properties","dimensional","debiasing","kolmogorov","technical","involving","frequently","formulate","confidence","inference","uniformly","simulation","functionals","dimension","estimator","independent","theoretical","constraint","conditional","cardinality"],"y":[29,5,10,13,76,2,58,2,120,135,35,294,2,282,231,11,4,62,13,744,122,87,37,4,90,92,101,26,18,16,200,23,97,176,343,30,502,2,14,572,82,405,27,108,30,289,64,238,670,118,10,19,52,71,73,118,21,15,49,385,171,37,49,118,10,99,0,98,248,153,47,0,1,411,2,147,123,341,3,110,242,46,113,33,77,37,33,10,124,156,9,399,8,21,159,99,48,382,27,39,153,58,22,91,17,143,854,29,29,370,109,66,53,66,145,2,1,62,45,157,39,81,8,22,42,2,32,59,352,6,52,5,53,1,181,6,851,149,44,14,169,32,1,19,70,126,575,46,1,28,58,22,627,190,31,264,191,38,278,51,69,141,127,310,109,31,14,278,38,25,90,5,26,26,0,89,38,115,13,47,240,189,0,1,41,43,32,52,40,226,14,70,3,67,26,130,148,96,103,12],"type":"bar"},{"x":["equivalence","semantical","reductions","nonmonotonic","polynomial","quantifi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4542,), (4542, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8116666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fuzzy</span> <span style=''>Object</span> <span style=''>Oriented</span> <span style=''>Dynamic</span> <span style=''>Networks</span> <span style=''>I</span> <br/><br/><span style=''>The</span> <span style=''>concepts</span> <span style=''>of</span> <span style=''>fuzzy</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>their</span> <span style=''>classes</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.30357142857142855);'>described</span> <span style=''>that</span> <span style=''>make</span> <span style=''>it</span> <span style=''>possible</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>structurally</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>represent</span> <span style='background-color:rgba(0, 255, 0, 0.43673469387755093);'>knowledge</span> <span style=''>about</span> <span style=''>fuzzy</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style=''>defined</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>their</span> <span style=''>classes</span> <span style='background-color:rgba(0, 255, 0, 0.49056603773584906);'>Operations</span> <span style=''>over</span> <span style=''>such</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>classes</span> <span style=''>are</span> <span style=''>also</span> <span style=''>proposed</span> <span style=''>that</span> <span style=''>make</span> <span style=''>it</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>sets</span> <span style=''>and</span> <span style=''>new</span> <span style=''>classes</span> <span style=''>of</span> <span style=''>fuzzy</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>also</span> <span style=''>to</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.5116279069767442);'>variations</span> <span style=''>in</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influence</span> <span style=''>of</span> <span style=''>external</span> <span style=''>factors</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Convergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diagnostics</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>with</span> <span style=''>constant</span> <span style=''>step</span> <span style=''>size</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>exhibit</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transient</span> <span style=''>phase</span> <span style=''>followed</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>phase</span> <span style=''>During</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transient</span> <span style=''>phase</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>towards</span> <span style=''>a</span> <span style=''>region</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>and</span> <span style=''>during</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>phase</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>oscillates</span> <span style=''>in</span> <span style=''>that</span> <span style=''>region</span> <span style=''>commonly</span> <span style=''>around</span> <span style=''>a</span> <span style=''>single</span> <span style=''>point</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diagnostic</span> <span style=''>test</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>such</span> <span style=''>phase</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>with</span> <span style=''>constant</span> <span style=''>learning</span> <span style=''>rate</span> <span style=''>We</span> <span style=''>present</span> <span style=''>theory</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>suggesting</span> <span style=''>that</span> <span style=''>the</span> <span style=''>region</span> <span style=''>where</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diagnostic</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coincides</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>region</span> <span style=''>For</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999997);'>Wasserstein</span> <span style=''>Loss</span> <br/><br/><span style=''>Learning</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>multi</span> <span style=''>label</span> <span style=''>outputs</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.37569060773480667);'>challenging</span> <span style=''>but</span> <span style=''>in</span> <span style=''>many</span> <span style=''>problems</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>metric</span> <span style=''>on</span> <span style=''>the</span> <span style=''>outputs</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>improve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>for</span> <span style=''>multi</span> <span style=''>label</span> <span style=''>learning</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999997);'>Wasserstein</span> <span style=''>distance</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999997);'>Wasserstein</span> <span style=''>distance</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dissimilarity</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>measures</span> <span style=''>Although</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>the</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999997);'>Wasserstein</span> <span style=''>distance</span> <span style=''>is</span> <span style=''>costly</span> <span style=''>recent</span> <span style=''>work</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.30357142857142855);'>described</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3422818791946309);'>regularized</span> <span style='background-color:rgba(255, 0, 0, 0.3084112149532711);'>approximation</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>computed</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999997);'>Wasserstein</span> <span style=''>distance</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>measures</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unnormalized</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bias</span> <span style=''>Variance</span> <span style=''>Tradeoff</span> <span style=''>of</span> <span style=''>Graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Laplacian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularizer</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>bias</span> <span style=''>variance</span> <span style=''>tradeoff</span> <span style=''>of</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Laplacian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizer</span> <span style=''>which</span> <span style=''>is</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style=''>graph</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>and</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>The</span> <span style=''>scaling</span> <span style=''>law</span> <span style=''>of</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specified</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style=''>spectral</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>and</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>signal</span> <span style=''>to</span> <span style=''>noise</span> <span style=''>ratio</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>which</span> <span style=''>suggests</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selecting</span> <span style=''>a</span> <span style=''>mediocre</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>suboptimal</span> <span style=''>The</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>three</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>random</span> <span style=''>band</span> <span style=''>limited</span> <span style=''>and</span> <span style=''>multiple</span> <span style=''>sampled</span> <span style=''>graph</span> <span style=''>signals</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>and</span> <span style=''>real</span> <span style=''>world</span> <span style=''>graphs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>near</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style=''>analysis</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10183875530410184)
# 	architecture (0.0876944837340877)
# 	experimental (0.13083451202263083)
# 	knowledge (0.12446958981612447)
# 	representation (0.13613861386138615)
# 	segmentation (0.07425742574257425)
# 	detection (0.12128712871287128)
# 	recognition (0.12057991513437058)
# 	different (0.26308345120226306)
# 	convolutional (0.13507779349363508)
#
# Some Statistics words are:
# 	stochastic (0.14858012170385396)
# 	statistical (0.15567951318458417)
# 	theoretical (0.1577079107505071)
# 	variables (0.14503042596348883)
# 	distribution (0.1830628803245436)
# 	estimation (0.1795131845841785)
# 	algorithm (0.42190669371196754)
# 	dimensional (0.1881338742393509)
# 	inference (0.2013184584178499)
# 	regression (0.18864097363083165)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="852b9ac4-3cd4-4430-9bb7-e7cb2fe717fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("852b9ac4-3cd4-4430-9bb7-e7cb2fe717fa")) {                    Plotly.newPlot(                        "852b9ac4-3cd4-4430-9bb7-e7cb2fe717fa",                        [{"x":["equivalence","semantical","reductions","nonmonotonic","polynomial","quantifications","additionally","permitted","associated","considered","precisely","computational","skeptical","particular","complexity","quantified","characterising","consistency","equilibrium","different","reasoning","extension","combinations","encodings","arbitrary","semantics","classical","propositional","calculate","customers","developed","identifies","precision","automatically","detection","situation","classification","restaurants","translate","framework","relationship","applications","interactive","component","transformed","available","graphical","application","information","development","translating","conceptual","mathematical","contribution","relationships","convergence","supported","analytics","management","representation","probabilistic","monitoring","constrained","classifiers","accomplish","combining","actigraphy","environments","architecture","computation","motivated","cigarette","respiration","efficient","delivering","objective","computing","recognition","interventions","structured","parameters","potentially","generalization","detectors","resources","integrating","heterogeneous","concentrate","classifier","combination","augmenting","approaches","synthetically","plausible","understanding","additional","experimentally","convolutional","backpropagation","transformations","investigate","generates","overfitting","improving","transforms","synthetic","performance","augmentation","handwritten","experimental","regression","simulated","likelihood","introduces","efficiently","regressors","interdependency","criterion","validation","selection","multimodal","numerical","estimations","parameterized","uncertain","attaching","expressed","qualitative","knowledge","certainty","operators","axiomatization","partially","quadratically","estimation","aggregates","algorithm","furthermore","factorization","nonnegative","extensive","quadratic","autocorrelation","consumption","observations","individual","experiments","measurements","electricity","relaxation","illustrate","recovering","algorithms","effectiveness","incremental","outperforms","benchmark","guarantee","effective","iteration","guarantees","stochastic","implementation","optimization","variables","desirable","preserved","including","projection","iterations","regularization","sacrificing","coordinate","randomized","quantiles","successfully","formulated","procedure","estimators","hypothesis","properties","dimensional","debiasing","kolmogorov","technical","involving","frequently","formulate","confidence","inference","uniformly","simulation","functionals","dimension","estimator","independent","theoretical","constraint","conditional","cardinality","restricted","contributions","significantly","consistent","functions","systematically","previously","regarding","satisfied","efficiency","convexity","condition","chemometrics","manuscript","decomposition","separation","constraints","variability","nonnegativity","challenges","variations","introduced","following","candidates","implement","preference","consecutive","specifically","preferred","candidate","preconditioner","acceleration","gradients","impossible","decoupled","expressiveness","mathematically","complicates","overparameterized","regularizer","accelerate","increasing","sometimes","conventional","transitioning","interactions","artificial","differently","individuals","coordinated","conditions","participate","andersson","interacti ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	actigraphy
# 	cigarette
# 	quantiles
# 	debiasing
# 	prohibits
# 	scientist
# 	discrepancies
# 	covariances
# 	trilinear
# 	integrable
# 	eigenstructures
# 	unavoidably
# 	certificate
# 	ellipsoidal
# 	particulars
# 	geostatistical
# 	sparsities
# 	mcdiarmids
# 	penalization
# 	noticeably
# Some words which never appear in Statistics papers:
# 	semantical
# 	nonmonotonic
# 	skeptical
# 	characterising
# 	encodings
# 	propositional
# 	certainty
# 	axiomatization
# 	followers
# 	monocular
# 	malignancy
# 	attenuation
# 	superresolution
# 	narration
# 	instruction
# 	assembled
# 	linguists
# 	linguistically
# 	syntactical
# 	automaton

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0467369447321922e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7608333333333334
